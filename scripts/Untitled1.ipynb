# %%
import ipykernel
print(ipykernel.__version__)
# import matplotlib as mpl
import bioframe
# Out:
# 7.2.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6748/4258933752.py in <cell line: 0>()
#       2 print(ipykernel.__version__)
#       3 # import matplotlib as mpl
# ----> 4 import bioframe
#
# ~/venv/chess/lib/python3.12/site-packages/bioframe/__init__.py in <module>
#     154     trim,
#     155 )
# --> 156 from .vis import plot_intervals, to_ucsc_colorstring
#     157
#     158 del version, PackageNotFoundError
#
# ~/venv/chess/lib/python3.12/site-packages/bioframe/vis.py in <module>
#       3
#       4 import matplotlib as mpl
# ----> 5 import matplotlib.pyplot as plt
#       6 import numpy as np
#       7 import pandas as pd
#
# ~/venv/chess/lib/python3.12/site-packages/matplotlib/pyplot.py in <module>
#    2228     dict.__setitem__(rcParams, "backend", rcsetup._auto_backend_sentinel)
#    2229 # Set up the backend.
# ...
